# %% [markdown]
# # Data Science – Parkinson's Disease Classification
# https://fenix.tecnico.ulisboa.pt/disciplinas/CDadosi7/2019-2020/1-semestre
#
# ---
#
# The students should perform a statistical analysis of the datasets in advance and summarize relevant implications in the report, such as the underlying distributions and hypothesized forms feature dependency.
# ## Preprocessing
# In accordance with the properties of the input dataset and the behavior of the target learning algorithm, the
# students are allowed to apply preprocessing techniques when needed or under a solid conjecture of its potential
# impact on learning.
#
# ## Data Set Information
# The data used in this study were gathered from 188 patients with PD (107 men and 81 women) with ages ranging from 33 to 87 (65.1Â±10.9) at the Department of Neurology in CerrahpaÅŸa Faculty of Medicine, Istanbul University. The control group consists of 64 healthy individuals (23 men and 41 women) with ages varying between 41 and 82 (61.1Â±8.9). During the data collection process, the microphone is set to 44.1 KHz and following the physicianâ€™s examination, the sustained phonation of the vowel /a/ was collected from each subject with three repetitions.
#
# ## Attribute Information
# Various speech signal processing algorithms including Time Frequency Features, Mel Frequency Cepstral Coefficients (MFCCs), Wavelet Transform based Features, Vocal Fold Features and TWQT features have been applied to the speech recordings of Parkinson's Disease (PD) patients to extract clinically useful information for PD assessment.
#
# ---
# ---

# %% [markdown]
# #### TODO:
# - [ ] Try to use the dataset with averaging of the ID's
# - [ ] See the clusters only for persons who have (or not have) a parkinsons
# - [ ] Add the ROC AUC chart for each classifier
#     -> will need to do validation dataset :(
# - [x] Try the LDA instead of PCA -> does not work with negative vals
# - [x] **Implement association rules.**

# %%
import warnings
warnings.filterwarnings('ignore')

from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')

# %%
# %%html
# <style>table {display: inline-block}</style>
# Out:
# <style>table {display: inline-block}</style>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
# Read the dataset and skip the first row
df = pd.read_csv("dataset/pd_speech_features.csv", skiprows=1)

# %% [markdown]
# ## 1. Statistical description (5%)

# %%
# The dataset consists of 755 columns
df.columns
# Out:
# Index(['id', 'gender', 'PPE', 'DFA', 'RPDE', 'numPulses', 'numPeriodsPulses',
#        'meanPeriodPulses', 'stdDevPeriodPulses', 'locPctJitter',
#        ...
#        'tqwt_kurtosisValue_dec_28', 'tqwt_kurtosisValue_dec_29',
#        'tqwt_kurtosisValue_dec_30', 'tqwt_kurtosisValue_dec_31',
#        'tqwt_kurtosisValue_dec_32', 'tqwt_kurtosisValue_dec_33',
#        'tqwt_kurtosisValue_dec_34', 'tqwt_kurtosisValue_dec_35',
#        'tqwt_kurtosisValue_dec_36', 'class'],
#       dtype='object', length=755)

# %%
# Describe the dataset
df.describe()
# Out:
#                id      gender         PPE         DFA        RPDE   numPulses  \
# count  756.000000  756.000000  756.000000  756.000000  756.000000  756.000000
# mean   125.500000    0.515873    0.746284    0.700414    0.489058  323.972222
# std     72.793721    0.500079    0.169294    0.069718    0.137442   99.219059
# min      0.000000    0.000000    0.041551    0.543500    0.154300    2.000000
# 25%     62.750000    0.000000    0.762833    0.647053    0.386537  251.000000
# 50%    125.500000    1.000000    0.809655    0.700525    0.484355  317.000000
# 75%    188.250000    1.000000    0.834315    0.754985    0.586515  384.250000
# max    251.000000    1.000000    0.907660    0.852640    0.871230  907.000000
#
#        numPeriodsPulses  meanPeriodPulses  stdDevPeriodPulses  locPctJitter  \
# count        756.000000        756.000000          756.000000    756.000000
# mean         322.678571          0.006360            0.000383      0.002324
# ...

# %%
df.head()
# Out:
#    id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0   0       1  0.85247  0.71826  0.57227        240               239
# 1   0       1  0.76686  0.69481  0.53966        234               233
# 2   0       1  0.85083  0.67604  0.58982        232               231
# 3   1       0  0.41121  0.79672  0.59257        178               177
# 4   1       0  0.32790  0.79782  0.53028        236               235
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 0          0.008064            0.000087       0.00218  ...
# 1          0.008258            0.000073       0.00195  ...
# 2          0.008340            0.000060       0.00176  ...
# 3          0.010858            0.000183       0.00419  ...
# 4          0.008162            0.002669       0.00535  ...
#
#    tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# 0                     1.5620                     2.6445
# 1                     1.5589                     3.6107
# ...

# %% [markdown]
# #### How many participants are in the dataframe?

# %%
print("There are", len(df.groupby(df.id).first().gender), "unique participant ids in the dataset.")
# Out:
# There are 252 unique participant ids in the dataset.

# %% [markdown]
# #### Are all of the records of each participant already classified?
# Or is there anybody who was had no Parkinsons but then turned out to be positive?

# %%
# There are no people who were diagnosed with alzheimer after the measurements were started
df.groupby([df["id"]])["class"].mean().isin([0, 1]).value_counts()
# Out:
# True    252
# Name: class, dtype: int64

# %% [markdown]
# #### Are there any missing values?

# %%
print("There are %d NA and %d null values." % (df[df.isna().any(axis=1)].__len__(), df[df.isnull().any(axis=1)].__len__()))
# Out:
# There are 0 NA and 0 null values.

# %% [markdown]
# #### Gender vs target variable

# %%
import seaborn as sns

# How does the parkinsons disease depend on the gender?
plot = sns.catplot(x="class", col="gender", data=df, kind="count")

# %% [markdown]
# #### Target variable

# %%
fig, ax = plt.subplots()
fig = df["class"].value_counts().plot(kind="bar", ax=ax)
ax.set_title("Distribution of the target classification variable")
plt.show()

# %% [markdown]
# #### Histograms for each variable

# %%
columns_start = 1
columns_end = 21

def choose_grid(nr):
    # // 4 + 1
    return nr // 4, 4

# %%
#look at distribution of first 10 variables
from pylab import *

plt.figure(figsize=(14, 14))

for i in range(2, 11):
    subplot(4,3, i - 1)
    sns.distplot(df.iloc[:, i])

# %%
columns = df.iloc[:,columns_start:columns_end].select_dtypes(include='number').columns
rows, cols = choose_grid(len(columns))
plt.figure()
fig, axs = plt.subplots(rows, cols, figsize=(cols*4, rows*4), squeeze=False)
i, j = 0, 0
for n in range(len(columns)):
    axs[i, j].set_title('Histogram for %s'%columns[n])
    axs[i, j].set_xlabel(columns[n])
    axs[i, j].set_ylabel("probability")
    axs[i, j].hist(df.iloc[:,columns_start:columns_end][columns[n]].dropna().values, 'auto')
    i, j = (i + 1, 0) if (n+1) % cols == 0 else (i, j + 1)
fig.tight_layout()
plt.show()

# %% [markdown]
# #### Correlation matrix
# The number of paramaters is really high

# %%
cmap = sns.diverging_palette(h_neg=210, h_pos=350, as_cmap=True)
graph = sns.clustermap(df.corr(), figsize=(18, 18), cmap=cmap);
a = graph.ax_heatmap.set_xticklabels([])
a = graph.ax_heatmap.set_yticklabels([])

# %% [markdown]
# #### Correlation of attributes with the target variable

# %%
# Calculate the correlation of each attribute
corcolumns = df.drop(columns=["class"]).corrwith(df["class"])
corcolumns = pd.DataFrame(corcolumns, columns=["correlation"])
corcolumns["abs_correlation"] = abs(corcolumns.correlation)

# Sort the most correlated values
corcolumns = corcolumns.sort_values(by="abs_correlation", ascending=False)

# %%
fig, ax = plt.subplots(figsize=(19, 10))
corcolumns.correlation.plot(kind="bar", title="Correlation of different attributes with the target variable", ax=ax)
ax.set_xticklabels([])
plt.show()

# %%
plt.figure(figsize=(10, 5))
ax = corcolumns.abs_correlation.iloc[:20].plot(kind="bar", title="20 Most correlated columns in the dataset with the target variable")
ax.set_ylabel("absolute correlation with target class")
ax.set_ybound(lower=0.3)
plt.show()

# %% [markdown]
# ## Preprocessing (20%)
# - Average the data samples?
# - Create 3 different datasets by each patient?
# - **Remove outliers?**
#
# **Tips from the lab:**
# - subsampling
#     - select only some of the data
# - oversampling
#     - suplicate some data
#     - works for some algorithms
# - SMOTE
#     - looks for similiar variables

# %% [markdown]
# ### Remove duplicates

# %%
dups = df[df.duplicated()]
print("The dataset contains {} duplicates - ID(s): {}".format(len(dups), dups.id.values))

# Drop the duplicate values
df = df.drop_duplicates()
# Out:
# The dataset contains 1 duplicates - ID(s): [37]

# %% [markdown]
# ### Train / Test Split
#
# - Stratified validation?
# - Should preprocessing be done inside cross validation?
#
# 20% of the data is put away for testing. Cross validation is used instead of the train/test array.

# %%
test_size = 0.2

# %% [markdown]
# Custom train/test split assures that there are no samples of same ID mixed in the train/valid dataset.

# %%
from sklearn.model_selection import train_test_split, GroupKFold
from sklearn.metrics import accuracy_score

train_id, test_id = next(GroupKFold(n_splits=6).split(df, groups=df.id))

# %%
from sklearn.model_selection import StratifiedKFold

# Shuffle the dataframe
df = df.sample(frac=1)

classes = pd.DataFrame(df.groupby("id").first()["class"])

train_id, test_id = next(StratifiedKFold(n_splits=6).split(classes, classes["class"]))
train_df, test_df = (df[df.id.isin(train_id)], df[df.id.isin(test_id)])

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
train_df["class"].value_counts().plot(kind="bar", title="train_df contains %d samples" % len(train_df))
plt.subplot(1, 2, 2)
test_df["class"].value_counts().plot(kind="bar", title="test_df contains %d samples" % len(test_df))
plt.tight_layout()
plt.show()

vc = train_df["class"].value_counts()
print("Performance of naive model that only predicts one class should be {:0.4f}.".format(1 - (vc[0] / vc[1])))
# Out:
# Performance of naive model that only predicts one class should be 0.6603.

# %% [markdown]
# #### K-Fold CV

# %%
from sklearn.preprocessing import Normalizer, StandardScaler

# %%
X_train = train_df.drop(columns=["class"])
y_train = train_df["class"]
X_test = test_df.drop(columns=["class"])
y_test = test_df["class"]

X_train_c = X_train.drop(columns=["id"])
X_train_n = pd.DataFrame(Normalizer().fit_transform(X_train_c), columns=X_train_c.columns)
X_train_s = pd.DataFrame(StandardScaler().fit_transform(X_train_c), columns=X_train_c.columns)

gkf_c = list(GroupKFold(n_splits=5).split(X_train_c, y_train, X_train.id))
gkf_n = list(GroupKFold(n_splits=5).split(X_train_n, y_train, X_train.id))
gkf_s = list(GroupKFold(n_splits=5).split(X_train_s, y_train, X_train.id))

# %% [markdown]
# ## Unsupervised (15%)
# - Association Rules (7.5%)
# - Clustering (7.5%)

# %% [markdown]
# ### Association Rules (7.5%)

# %% [markdown]
# First we need to convert numerical data to binary.

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Top 20 features generated from SelectKBest
KBestSelector = SelectKBest(f_classif).fit(X_train_c, y_train)
feature_scores = pd.DataFrame({"Feature": X_train_c.columns, "Scores": KBestSelector.scores_})
top20k = feature_scores.sort_values(by="Scores", ascending=False)["Feature"].iloc[:20].values

# Sanity check
top20c = corcolumns.abs_correlation[:20].index.values
print("{} out of 20 most correlated values overlap with SelectKBest".format(len(np.intersect1d(top20k, top20c))))

# Select top x columns
df_top20cols = X_train_c.loc[:, X_train_c.columns.isin(top20k)]
df_top20cols["class"] = y_train
# Out:
# 15 out of 20 most correlated values overlap with SelectKBest

# %%
dummyfiedDF = pd.DataFrame()

for col in df_top20cols:
    if col != "class":
        cutdf = pd.cut(df_top20cols[col], 3, labels=[0, 1, 2])
        dummydf = pd.get_dummies(cutdf)
        seriesname = dummydf.columns.name
        dummydf.columns = [seriesname + "_low", seriesname + "_mid", seriesname + "_high"]
        dummyfiedDF = pd.concat([dummyfiedDF, dummydf], axis=1)
    else:
        dummyfiedDF = pd.concat([dummyfiedDF, df_top20cols[col]], axis=1)

# %%
from mlxtend.frequent_patterns import apriori, association_rules
from sklearn.preprocessing import LabelBinarizer

frequent_itemsets = {}
minpaterns = 2000
minsup = 0.9
classrules = None
while minsup > 0:    
    minsup = minsup * 0.9
    frequent_itemsets = apriori(dummyfiedDF, min_support=minsup, use_colnames=True, verbose=3)
    
    frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
    classrules = rules[rules['consequents'] == {'class'}]
    
    print("Minsup {} found {} patterns out of which {} contain class consequent"
          .format(minsup, len(frequent_itemsets), len(classrules)))  
    
    if len(classrules) > 20:
        break
    
    """if len(frequent_itemsets) >= minpaterns:
        print("Minimum support:", minsup)
        print("Number of found patterns:", len(frequent_itemsets))
        break"""
# Out:
# Processing 33 combinations | Sampling itemset size 110
# Minsup 0.81 found 2239 patterns out of which 0 contain class consequent
# Processing 42 combinations | Sampling itemset size 14132
# Minsup 0.7290000000000001 found 30591 patterns out of which 127 contain class consequent

# %%
select = classrules
select = select.sort_values(by=["confidence", "support", "leverage"], ascending=False)\
    [["antecedents", "consequents", "confidence", "support", "leverage"]].head(5).round(3)

select = select.rename(columns={"confidence": "conf", "support": "supp", "leverage": "lever"})
print(select.to_csv(index=False, sep=";").replace("frozenset({", "").replace("})", "").replace("'", "")\
     .replace(", ", "-"))

# %% [markdown]
# ### Clustering (7.5%)

# %%
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram

def dendrogram_plot(data, link="complete"):
    linkageMatrix = linkage(data, link)

    plt.xlabel('point index')
    plt.ylabel('distance')
    dendrogram(linkageMatrix, truncate_mode='lastp', p=24,
        leaf_rotation=90., leaf_font_size=8.)

# %%
plt.figure(figsize=(9, 4))
dendrogram_plot(X_train_n)
plt.title("hierarchical clustering as a dendrogram, complete linkage - normalized dataset")
# Out:
# Text(0.5, 1.0, 'hierarchical clustering as a dendrogram, complete linkage - normalized dataset')

# %%
plt.figure(figsize=(12, 12))
plt.subplot(3, 1, 1)
dendrogram_plot(X_train_c)
plt.title("hierarchical clustering as a dendrogram, complete linkage - raw dataset")

plt.subplot(3, 1, 2)
dendrogram_plot(X_train_n)
plt.title("hierarchical clustering as a dendrogram, complete linkage - normalized dataset")

plt.subplot(3, 1, 3)
dendrogram_plot(X_train_s)
plt.title("hierarchical clustering as a dendrogram, complete linkage - standardized dataset")

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import adjusted_rand_score
from scipy.cluster.hierarchy import fcluster
from sklearn.decomposition import PCA
import itertools

searchspace = {"linkage_type": ["single", "complete", "ward", "average"],
               "dataset": [ "X_train_n"], # "X_train_c", "X_train_s"
               "clust_count": np.arange(2, 8, 1)}

possibilities = len(list(itertools.product(*searchspace.values())))

# %%
ctr = 1
plt.figure(figsize=(21, 10))
for comb in itertools.product(*searchspace.values()):
    clust_count = comb[2]
    linkage_type = comb[0]
    dataname = ""
    
    if comb[1] == "X_train_c":
        data = X_train_c
        dataname = "raw"
    elif comb[1] == "X_train_n":
        data = X_train_n
        dataname = "normalised"
    elif comb[1] == "X_train_s":
        data = X_train_s
        dataname = "standardised"
    else:
        raise("Wrong dataset name entered.")

    linkageMatrix = linkage(data, linkage_type)
    clusters = fcluster(linkageMatrix, clust_count, criterion='maxclust')

    # Save the cluster number to the standardized dataset
    clustered = data.copy()
    clustered["cluster"] = clusters

    # Generate a different color for each cluster
    colors = cm.Accent(np.linspace(0, 1, len(np.unique(clusters))))

    # Reduce the dimensionality to 2D and plot the clusters.
    transformed = PCA(n_components=2).fit_transform(clustered.drop(columns=["cluster"]))

    transformed = pd.DataFrame(transformed, columns=["x", "y"])
    transformed["class"] = y_train.values
    transformed["cluster"] = clusters
    transformed["color"] = transformed.cluster.apply(lambda x: colors[x-1])

    transformed0 = transformed[transformed["class"] == 0]
    transformed1 = transformed[transformed["class"] == 1]

    # adjusted_rand_score(transformed["class"], transformed.cluster)
    titlestring = dataname + ", " + linkage_type + ", " + str(clust_count)
    
    ax = plt.subplot(possibilities / 6, 6, ctr)
    plt.title(titlestring)
    ax.set_ybound(-0.1, 0.2)
    ax.set_xbound(-0.1)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.scatter(transformed0.x, transformed0.y, c=transformed0.color, marker="o")
    ax.scatter(transformed1.x, transformed1.y, c=transformed1.color, marker="x")
    ctr = ctr + 1

plt.tight_layout()
plt.show()

# %% [markdown]
# #### KMeans clustering

# %%
from sklearn.cluster import KMeans
import numpy as np

def elbow_plot(data):
    # Find the best number of clusters
    inertia = []
    for i in range(1,25):
        kmeans = KMeans(n_clusters=i, random_state=420)
        kmeans.fit(data)
        inertia.append(kmeans.inertia_)

    # Plot the elbow graph
    plt.plot(range(1,25), inertia)
    plt.xlabel("k")
    plt.ylabel('utility function')
    return plt

# %% [markdown]
# - sub groups within the class
# - c_width
# - randindex

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
elbow_plot(X_train_c)
plt.title("raw data")

plt.subplot(1, 3, 2)
elbow_plot(X_train_s)
plt.title("standardized data")

plt.subplot(1, 3, 3)
elbow_plot(X_train_n)
plt.title("normalized data")

plt.tight_layout()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

def plot_3d(data, colors):
    fig = plt.figure(figsize=(15,10))
    ax = fig.add_subplot(111, projection='3d')
    ax.view_init(30, 240)
    for i, v in enumerate(sorted(data["cluster"].unique())):
        clusterdata = data[data["cluster"] == v]        
        cld_t = clusterdata[clusterdata["class"] == 1]
        cld_f = clusterdata[clusterdata["class"] == 0]
        ax.scatter(cld_t.x, cld_t.y, cld_t.z, c = colors[i], alpha=0.5, marker="x")
        ax.scatter(cld_f.x, cld_f.y, cld_f.z, c = colors[i], alpha=0.5, marker="o")


def plot_2d(data, colors):
    fig = plt.figure(figsize=(15,10))
    ax = fig.add_subplot(111)
    for i, v in enumerate(sorted(data["cluster"].unique())):
        clusterdata = data[data["cluster"] == v]
        cld_t = clusterdata[clusterdata["class"] == 1]
        cld_f = clusterdata[clusterdata["class"] == 0]
        ax.scatter(cld_t.x, cld_t.y, c = colors[i].T, alpha=0.5, marker="x")
        ax.scatter(cld_f.x, cld_f.y, c = colors[i].T, alpha=0.5, marker="o")

# %%
from sklearn.decomposition import PCA

dfc = X_train_n.copy()
dfc['cluster'] = KMeans(n_clusters=5, init='k-means++', random_state=420).fit_predict(X_train_n)

# Reduce dimensionality to 3D
_dfc = PCA(n_components=3).fit_transform(dfc.drop(columns=["cluster"]))

dfc["x"] = _dfc[:,0]
dfc["y"] = _dfc[:,1]
dfc["z"] = _dfc[:,2]
dfc['class'] = df["class"]

plot_3d(dfc, ["red", "green", "blue", "orange", "violet", "brown"])

# %%
dfc = X_train_n.copy()
dfc['cluster'] = KMeans(n_clusters=6, init='k-means++', random_state=420).fit_predict(X_train_n)

# Reduce dimensionality to 2D
_dfc = PCA(n_components=2).fit_transform(dfc.drop(columns=["cluster"]))

dfc["x"] = _dfc[:,0]
dfc["y"] = _dfc[:,1]

dfc['class'] = df["class"]

plot_2d(dfc, ["red", "green", "blue", "orange", "violet", "brown"])

# %%
# Get the index o f the orange outlier
outlierid = dfc[dfc.cluster == 3].index.values[0]
X_train[X_train.index == outlierid]
# Patient ID 202
# Out:
#       id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 606  202       0  0.83786  0.73017  0.70689         82                74
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 606          0.006768            0.001837       0.01119  ...
#
#      tqwt_kurtosisValue_dec_27  tqwt_kurtosisValue_dec_28  \
# 606                     7.1148                     5.8171
#
#      tqwt_kurtosisValue_dec_29  tqwt_kurtosisValue_dec_30  \
# 606                     5.8815                     4.1913
#
#      tqwt_kurtosisValue_dec_31  tqwt_kurtosisValue_dec_32  \
# 606                     4.0224                     3.1601
#
#      tqwt_kurtosisValue_dec_33  tqwt_kurtosisValue_dec_34  \
# 606                     2.7833                     3.8495
#
#      tqwt_kurtosisValue_dec_35  tqwt_kurtosisValue_dec_36
# 606                     5.0696                    11.1724
#
# [1 rows x 754 columns]

# %%
X_train[X_train.id == 202]
# Out:
#       id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 607  202       0  0.58062  0.68208  0.69896        165               159
# 606  202       0  0.83786  0.73017  0.70689         82                74
# 608  202       0  0.78751  0.70383  0.84750        164               158
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 607          0.007961            0.000973       0.00982  ...
# 606          0.006768            0.001837       0.01119  ...
# 608          0.006750            0.001521       0.00496  ...
#
#      tqwt_kurtosisValue_dec_27  tqwt_kurtosisValue_dec_28  \
# 607                     3.7581                     3.9575
# 606                     7.1148                     5.8171
# 608                     6.9622                     8.8122
#
#      tqwt_kurtosisValue_dec_29  tqwt_kurtosisValue_dec_30  \
# 607                     4.9726                     2.7589
# 606                     5.8815                     4.1913
# ...

# %% [markdown]
# ## Classification (20%)
# - Naïve Bayes (2%)
# - Instance-based Learning (3%)
# - Decision Trees (5%)
# - Random Forests (5%)
# - XGBoost (5%)

# %%
# ROC AUC plot function
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def get_roc_auc_plot(classifier, _X_train, _y_train, _split_groups, title="", titlesize=10):
    i = 0
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for train, test in gkf_c:
        i += 1
        probas_ = classifier.fit(_X_train.iloc[train], _y_train.iloc[train]).predict_proba(_X_train.iloc[test])
        # Compute ROC curve and area the curve
        fpr, tpr, thresholds = roc_curve(_y_train.iloc[test], probas_[:, 1])
        tprs.append(interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        plt.plot(fpr, tpr, lw=1, alpha=0.3,
                 label='ROC fold %d (AUC = %0.2f)' % (i, roc_auc))

    
    plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
             label='Chance', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    plt.plot(mean_fpr, mean_tpr, color='b',
             label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=2, alpha=.8)

    std_tpr = np.std(tprs, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
    plt.fill_between(mean_fpr, tprs_lower, tprs_upper, color='grey', alpha=.2,
                     label=r'$\pm$ 1 std. dev.')

    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(title, fontsize=titlesize)
    plt.legend(loc="lower right")
    return plt

# %%
# Best model results are stored in the results dictionary
results = {}

# %% [markdown]
# ### Dummy classifier

# %%
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import cross_val_score

dummy = DummyClassifier()
results["DummyClassifier"] = cross_val_score(dummy, X_train_c, y_train, cv=gkf_c, verbose=0, n_jobs=8).mean()
print("DummyClassifier score: {:0.4f}.".format(results["DummyClassifier"]))
# Out:
# DummyClassifier score: 0.6220.

# %%
plt.figure(figsize=(6, 6))
plt1 = get_roc_auc_plot(DummyClassifier(), X_train_c, y_train, gkf_c, 
                        "DummyClassifier", 10)

# %% [markdown]
# ### GaussianNB - Naïve Bayes (2%)
# - Does not work with correlated columns

# %% [markdown]
# #### Original dataset

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score

gaus = GaussianNB()
results["GaussianNB"] = cross_val_score(gaus, X_train_c, y_train, cv=gkf_c, verbose=0, n_jobs=8).mean()
print("GaussianNB score: {:0.4f}".format(results["GaussianNB"]))
# Out:
# GaussianNB score: 0.7185

# %% [markdown]
# #### Select K best parameters
# Best value 0.8119 with k=13.

# %%
from sklearn.feature_selection import SelectKBest, f_classif

x, y = ([], [])
for i in range(1, 64, 1):
    XX = SelectKBest(f_classif, k=i).fit_transform(X_train_c, y_train)
    g = GaussianNB().fit(XX, y_train)
    x.append(i)
    y.append(cross_val_score(g, XX, y_train, cv=gkf_c, n_jobs=8).mean())

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("SelectKBest attributes for NB classifier")
ax.axvline(y.index(max(y))+1, c="red")
plt.show()

print("Best value {:0.4f} with k={}.".format(max(y), x[y.index(max(y))]))
# Out:
# Best value 0.8119 with k=13.

# %%
plt.figure(figsize=(6, 6))
plt1 = get_roc_auc_plot(GaussianNB(), pd.DataFrame(SelectKBest(f_classif, k=13).fit_transform(X_train_c, y_train)), y_train, gkf_c, 
                        "GaussianNB", 10)

# %% [markdown]
# #### PCA (Try out LDA)
# Best value 0.7654 with k=1.

# %%
from sklearn.decomposition import PCA

x, y = ([], [])
for i in range(1, 24, 1):
    XX = PCA(n_components=i).fit_transform(X_train_c)
    g = GaussianNB().fit(XX, y_train)
    x.append(i)
    y.append(cross_val_score(g, XX, y_train, cv=gkf_c, n_jobs=8).mean())

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("PCA attributes for NB classifier")
ax.axvline(y.index(max(y))+1, c="red")
plt.show()

print("Best value {:0.4f} with k={}.".format(max(y), x[y.index(max(y))]))
# Out:
# Best value 0.7654 with k=1.

# %% [markdown]
# ### KNeighborsClassifier – Instance-based Learning (3%)
# KNeighborsClassifier best score: 0.7480 for {'algorithm': 'auto', 'leaf_size': 2, 'n_neighbors': 5, 'weights': 'uniform'}.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

grid = {'n_neighbors': np.arange(1, 15),
        'metric': ["euclidean", "manhattan", "minkowski"],
        'leaf_size': np.arange(2, 40, 5)}

knnclas_raw = GridSearchCV(KNeighborsClassifier(), grid, cv=gkf_c, verbose=0, n_jobs=8, iid=False)\
    .fit(X_train_c, y_train)
knn_raw_score = knnclas_raw.best_score_.mean()
print("KNeighborsClassifier best score: {:0.4f} for {}.".format(knnclas_raw.best_score_, knnclas_raw.best_params_))
# Out:
# KNeighborsClassifier best score: 0.7477 for {'leaf_size': 2, 'metric': 'euclidean', 'n_neighbors': 5}.

# %% [markdown]
# ##### Normalized data
# KNeighborsClassifier best score: 0.7511961722488039 for {'algorithm': 'auto', 'leaf_size': 2, 'n_neighbors': 13, 'weights': 'uniform'}.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

grid = {'n_neighbors': np.arange(1, 15),
        'metric': ["euclidean", "manhattan", "minkowski"],
        'leaf_size': np.arange(2, 40, 5)}

knnclas_norm = GridSearchCV(KNeighborsClassifier(), grid, cv=gkf_n, verbose=0, n_jobs=8, iid=False)\
    .fit(X_train_n, y_train)
knn_normal_score = knnclas_norm.best_score_.mean()
print("KNeighborsClassifier best score: {:0.4f} for {}.".format(knnclas_norm.best_score_, knnclas_norm.best_params_))
# Out:
# KNeighborsClassifier best score: 0.7509 for {'leaf_size': 2, 'metric': 'euclidean', 'n_neighbors': 13}.

# %% [markdown]
# ##### Standardized data
# KNeighborsClassifier best score: 0.8229665071770335 for {'algorithm': 'auto', 'leaf_size': 2, 'n_neighbors': 14, 'weights': 'uniform'}.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

grid = {'n_neighbors': np.arange(1, 15),
        'metric': ["euclidean", "manhattan", "minkowski"],
        'leaf_size': np.arange(2, 40, 5)}

knnclas_stand = GridSearchCV(KNeighborsClassifier(), grid, cv=gkf_s, verbose=0, n_jobs=8, iid=False)\
    .fit(X_train_s, y_train)
knn_standard_score = knnclas_stand.best_score_.mean()
print("KNeighborsClassifier best score: {:0.4f} for {}.".format(knnclas_stand.best_score_, knnclas_stand.best_params_))
# Out:
# KNeighborsClassifier best score: 0.8226 for {'leaf_size': 2, 'metric': 'euclidean', 'n_neighbors': 14}.

# %%
plt.figure(figsize=(18, 6))
plt.subplot(1, 3, 1)
plt1 = get_roc_auc_plot(KNeighborsClassifier(**knnclas_raw.best_params_), X_train_c, y_train, gkf_c, 
                        "KNeighborsClassifier - unmodified data\n" + str(knnclas_raw.best_params_))
plt1.plot()
plt.subplot(1, 3, 2)
plt2 = get_roc_auc_plot(KNeighborsClassifier(**knnclas_norm.best_params_), X_train_n, y_train, gkf_n,
                       "KNeighborsClassifier - normalised data\n" + str(knnclas_norm.best_params_))
plt2.plot()
plt.subplot(1, 3, 3)
plt3 = get_roc_auc_plot(KNeighborsClassifier(**knnclas_stand.best_params_), X_train_s, y_train, gkf_s,
                       "KNeighborsClassifier - standardized data\n" + str(knnclas_stand.best_params_))
plt3.plot()
plt.tight_layout()
plt.show()

# %%
scores = [knn_raw_score, knn_normal_score, knn_standard_score]

fig, ax = plt.subplots()
ax.bar(x=["raw data"], height=scores[0])
ax.bar(x=["normalized data"], height=scores[1])
ax.bar(x=["standardized data"], height=scores[2])
ax.set_xticklabels("")
ax.set_title("Comparison of KNN on different datasets.")
ax.legend(["raw data", "normalized data", "standardized data"])
ax.set_ybound(lower=0.6)
plt.show()

# %%
# Save the best score
results["KNeighborsClassifier"] = max(scores)

# %% [markdown]
# ### DecisionTreeClassifier - Decision Trees (5%)
# DecisionTreeClassifier best score: 0.7783 for {'criterion': 'gini', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 13}.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

grid = {'criterion': ['gini'],
        'min_samples_split' : np.arange(3, 15, 2),
        'min_samples_leaf' : np.arange(3, 5, 1),
        'max_depth': np.arange(4, 12, 1)}

dtc = GridSearchCV(DecisionTreeClassifier(), grid, cv=gkf_c, verbose=0, n_jobs=8, iid=False)\
    .fit(X_train_c, y_train)
results["DecisionTreeClassifier"] = dtc.best_score_.mean()
print("DecisionTreeClassifier best score: {:0.4f} for {}.".format(dtc.best_score_.mean(), dtc.best_params_))
# Out:
# DecisionTreeClassifier best score: 0.7735 for {'criterion': 'gini', 'max_depth': 6, 'min_samples_leaf': 4, 'min_samples_split': 9}.

# %%
# Modify the parameters for them to fit to the graph
treeparams = "{'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 5}"

plt.figure(figsize=(6, 6))
plt1 = get_roc_auc_plot(DecisionTreeClassifier(**dtc.best_params_), X_train_c, y_train, gkf_c, 
                        "DecisionTreeClassifier\n" + str(treeparams))

# %% [markdown]
# ### RandomForestClassifier - Random Forests (5%)
# RandomForestClassifier best score: 0.8434 for {'max_depth': 11, 'max_features': 7, 'min_samples_leaf': 2, 'min_samples_split': 0.001, 'n_estimators': 60}.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

grid = {'max_features' : np.arange(5, 9, 2),
        'n_estimators' : np.arange(30, 120, 30),
        'max_depth': np.arange(6, 13, 1),
        'min_samples_leaf': np.arange(1, 4, 1),
        'min_samples_split': np.arange(0.001, 0.002, 0.0005)}

randf = GridSearchCV(RandomForestClassifier(), grid, cv=gkf_c, verbose=0, n_jobs=8, iid=False)\
    .fit(X_train_c, y_train)
results["RandomForestClassifier"] = randf.best_score_.mean()
print("RandomForestClassifier best score: {:0.4f} for {}.".format(randf.best_score_.mean(), randf.best_params_))
# Out:
# RandomForestClassifier best score: 0.8482 for {'max_depth': 11, 'max_features': 7, 'min_samples_leaf': 1, 'min_samples_split': 0.0015, 'n_estimators': 60}.

# %%
randforestparams = "{'max_depth': 11, 'n_estimators': 60, 'max_features': 7, ...}"

plt.figure(figsize=(6, 6))
plt1 = get_roc_auc_plot(RandomForestClassifier(**randf.best_params_), X_train_c, y_train, gkf_c, 
                        "RandomForestClassifier\n" + randforestparams, 10)

# %%
# Both dt and rf
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt1 = get_roc_auc_plot(DecisionTreeClassifier(**dtc.best_params_), X_train_c, y_train, gkf_c, 
                        "DecisionTreeClassifier\n" + str(treeparams))

plt.subplot(1, 2, 2)
plt1 = get_roc_auc_plot(RandomForestClassifier(**randf.best_params_), X_train_c, y_train, gkf_c, 
                        "RandomForestClassifier\n" + randforestparams, 10)

# %% [markdown]
# ### XGBClassifier - XGBoost (5%)
# XGBClassifier best score: 0.8435 for {'n_estimators': 95, 'min_child_weight': 2.5, 'max_depth': 9, 'learning_rate': 0.14, 'gamma': 0.55, 'colsample_bytree': 0.8}.

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import KFold, cross_val_score, RandomizedSearchCV

grid = {"n_estimators": [90, 93, 95, 98],
        "learning_rate": [0.14, 0.15, 0.16],
        "max_depth": [7, 8, 9],
        "min_child_weight": [2.25, 2.5, 2.75],
        "gamma": [0.5, 0.55],
        "colsample_bytree": [0.78, 0.8]
       }

xgbclas = RandomizedSearchCV(XGBClassifier(), grid, cv=gkf_c, verbose=0, n_jobs=8, iid=False, n_iter=80)\
    .fit(X_train_c, y_train)
print("XGBClassifier best score: {:0.4f} for {}.".format(xgbclas.best_score_.mean(), xgbclas.best_params_))
results["XGBClassifier"] = xgbclas.best_score_.mean()
# Out:
# XGBClassifier best score: 0.8419 for {'n_estimators': 95, 'min_child_weight': 2.5, 'max_depth': 7, 'learning_rate': 0.15, 'gamma': 0.55, 'colsample_bytree': 0.8}.

# %%
xgbparams = "{'n_estimators': 90, 'max_depth': 8, 'learning_rate': 0.15,.. }"

# %%
plt.figure(figsize=(6, 6))
plt1 = get_roc_auc_plot(XGBClassifier(**xgbclas.best_params_), X_train_c, y_train, gkf_c, 
                        "XGBClassifier\n" + xgbparams, 10)

# %% [markdown]
# ### AdaBoostClassifier
# AdaBoostClassifier best score: 0.8306 for {'algorithm': 'SAMME.R', 'learning_rate': 1, 'n_estimators': 95}.

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV

grid = {'n_estimators': np.arange(90, 100, 2),
        'learning_rate' : [0.8, 0.9, 1, 1.1],
        'algorithm' : ['SAMME', 'SAMME.R']}

adaclass = GridSearchCV(AdaBoostClassifier(), grid, cv=gkf_c, verbose=0, n_jobs=8, iid=False)\
    .fit(X_train_c, y_train)
print("AdaBoostClassifier best score: {:0.4f} for {}.".format(adaclass.best_score_.mean(), adaclass.best_params_))
results["AdaBoostClassifier"] = adaclass.best_score_.mean()
# Out:
# AdaBoostClassifier best score: 0.8289 for {'algorithm': 'SAMME', 'learning_rate': 0.9, 'n_estimators': 96}.

# %%
adaparams = adaclass.best_params_

# %%
plt.figure(figsize=(6, 6))
plt1 = get_roc_auc_plot(AdaBoostClassifier(**adaclass.best_params_), X_train_c, y_train, gkf_c, 
                        "AdaBoostClassifier\n" + str(adaparams), 10)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt1 = get_roc_auc_plot(XGBClassifier(**xgbclas.best_params_), X_train_c, y_train, gkf_c, 
                        "XGBClassifier\n" + str(xgbparams))
plt1.plot()
plt.subplot(1, 2, 2)
plt2 = get_roc_auc_plot(AdaBoostClassifier(**adaclass.best_params_), X_train_c, y_train, gkf_c,
                       "AdaBoostClassifier\n" + str(adaparams))

# %% [markdown]
# ## Select the best classifier

# %%
import matplotlib
cm = matplotlib.cm.get_cmap("Accent")

# %%
import matplotlib.pyplot as plt

colors = cm(np.linspace(0, 1, len(results)))

fig, ax = plt.subplots()
ax.bar(range(len(results)), list(results.values()), align='center', color=colors)
ax.set_xticklabels(list(results.keys()), rotation="vertical")
ax.set_xticks(np.arange(len(results.keys())))
yticks = np.linspace(0.5, 1, 11)
ax.set_yticks(yticks)
ax.set_ybound(lower = 0.5, upper=1)
ax.set_yticklabels(['{:,.2%}'.format(x) for x in yticks])
ax.grid()
ax.title.set_text("Validation accuracy of tuned classifiers")
plt.show()

# %% [markdown]
# #### Print the ROC AUC curve for all of the cassifiers

# %%
# ROC AUC plot function
import numpy as np
from scipy import interp
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def get_averaged_roc_auc(classifier, _X_train, _y_train, _split_groups, title="", color='b', chance=False, globaltitle=""):
    i = 0
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)

    for train, test in gkf_c:
        i += 1
        probas_ = classifier.fit(_X_train.iloc[train], _y_train.iloc[train]).predict_proba(_X_train.iloc[test])
        # Compute ROC curve and area the curve
        fpr, tpr, thresholds = roc_curve(_y_train.iloc[test], probas_[:, 1])
        tprs.append(interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)

    if chance:
        plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r', alpha=.4)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)
    plt.plot(mean_fpr, mean_tpr, color=color,
             label=title + r' (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
             lw=2, alpha=.7)

    std_tpr = np.std(tprs, axis=0)
    tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
    tprs_lower = np.maximum(mean_tpr - std_tpr, 0)

    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    if globaltitle != "":
        plt.title(globaltitle, fontsize=10)
    plt.legend(loc="lower right")
    return plt

# %%
plt.figure(figsize=(10, 10))
#get_averaged_roc_auc(DummyClassifier(), X_train_c, y_train, gkf_c, 
#                        "DummyClassifier", colors[0], chance=True, globaltitle="Mean ROC AUC score across CV folds")
get_averaged_roc_auc(GaussianNB(), pd.DataFrame(SelectKBest(f_classif, k=13).fit_transform(X_train_c, y_train)), y_train, gkf_c, 
                        "GaussianNB", colors[1], chance=True, globaltitle="Mean ROC AUC score across CV folds")
get_averaged_roc_auc(KNeighborsClassifier(**knnclas_stand.best_params_), X_train_s, y_train, gkf_s,
                       "KNeighborsClassifier", colors[2])
get_averaged_roc_auc(DecisionTreeClassifier(**dtc.best_params_), X_train_c, y_train, gkf_c, 
                        "DecisionTreeClassifier", colors[3])
get_averaged_roc_auc(RandomForestClassifier(**randf.best_params_), X_train_c, y_train, gkf_c, 
                        "RandomForestClassifier", colors[4])
get_averaged_roc_auc(XGBClassifier(**xgbclas.best_params_), X_train_c, y_train, gkf_c, 
                        "XGBClassifier", colors[5])
get_averaged_roc_auc(AdaBoostClassifier(**adaclass.best_params_), X_train_c, y_train, gkf_c,
                       "AdaBoostClassifier", colors[6])
plt.show()

# %% [markdown]
# #### Train the model on the whole training data and evaluate testing dataset

# %%
final_classifier = XGBClassifier(**xgbclas.best_params_)
final_classifier.fit(X_train_c, y_train)

y_pred_bin = final_classifier.predict(X_test.drop(columns="id"))
y_pred_prb = final_classifier.predict_proba(X_test.drop(columns="id"))

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
print("Testing ROC AUC score", roc_auc_score(y_test, y_pred_prb[:, 1]))
print("Testing accuracy", accuracy_score(y_test, y_pred_bin))
# Out:
# Testing ROC AUC score 0.8216905901116428
# Testing accuracy 0.7734375
